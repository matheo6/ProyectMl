# %%
import gzip
import json
import ast
import pandas as pd

# %%
def readDataJson(ruta):
    data=[]
    with gzip.open(ruta, 'rb') as f:
        for line in f:
            data.append(json.loads(line.decode('utf-8')))
    return pd.DataFrame(data)

# %%
def readDataAst(ruta):
    data=[]
    with gzip.open(ruta, 'rb') as f:
        for line in f:
            data.append(ast.literal_eval(line.decode('utf-8')))
    return pd.DataFrame(data)

# %%
games2=readDataJson('steam_games.json.gz')
user_review2= readDataAst('user_reviews.json.gz')
user_items2=readDataAst('users_items.json.gz')

# %%
games2.dropna(how='all',inplace=True)
user_review2.dropna(how='all',inplace=True)
user_items2.dropna(how='all',inplace=True)

# %%
def unnest(df,column): 
    return pd.concat([df,pd.json_normalize(df.explode(column,ignore_index=True)[column])],axis=1).drop(columns=column)

# %%
lista_reviews=unnest(user_review2,'reviews')
lista_items=unnest(user_items2,'items')

# %%
lista_reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 59328                NaN                                                NaN
# 59329                NaN                                                NaN
# 59330                NaN                                                NaN
# 59331                NaN                                                NaN
# 59332                NaN                                                NaN
#
# ...

# %%
lista_items
# Out:
#                    user_id  items_count           steam_id  \
# 0        76561197970982479        277.0  76561197970982479
# 1                  js41637        888.0  76561198035864385
# 2                evcentric        137.0  76561198007712555
# 3               Riot-Punch        328.0  76561197963445855
# 4                    doctr        541.0  76561198002099482
# ...                    ...          ...                ...
# 5170010                NaN          NaN                NaN
# 5170011                NaN          NaN                NaN
# 5170012                NaN          NaN                NaN
# 5170013                NaN          NaN                NaN
# 5170014                NaN          NaN                NaN
#
#                                                   user_url item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...      10
# 1                     http://steamcommunity.com/id/js41637      20
# ...
